# %%
pip install kagglehub
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shubhamsingh42/flight-delay-dataset-2018-2024")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/angelawatson/.cache/kagglehub/datasets/shubhamsingh42/flight-delay-dataset-2018-2024/versions/1

# %%
import os

print(os.listdir(path))
# Out:
# ['flight_data.parquet', 'flight_data_2018_2024.csv', 'readme.html']

# %%
import os

DATA_DIR = "/Users/angelawatson/.cache/kagglehub/datasets/shubhamsingh42/flight-delay-dataset-2018-2024/versions/1"

print(os.listdir(DATA_DIR))
# Out:
# ['flight_data.parquet', 'flight_data_2018_2024.csv', 'readme.html']

# %%
import pandas as pd
import os

file_2018 = os.path.join(DATA_DIR, "flight_data_2018_2024.csv")

df_sample = pd.read_csv(file_2018, nrows=1_000_000)

print(df_sample.head())
print(df_sample.shape)
# Out:
# /var/folders/lv/dj7rpyhs59d0j61lff2g3l1r0000gn/T/ipykernel_4732/3293749838.py:6: DtypeWarning: Columns (11,13,86,93,94,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sample = pd.read_csv(file_2018, nrows=1_000_000)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2024        1      1          14          7  2024-01-14
# 1  2024        1      1          14          7  2024-01-14
# 2  2024        1      1          14          7  2024-01-14
# 3  2024        1      1          14          7  2024-01-14
# 4  2024        1      1          14          7  2024-01-14
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# 3                        UA                            UA_CODESHARE
# ...

# %%
df_all = pd.read_parquet("/Users/angelawatson/.cache/kagglehub/datasets/shubhamsingh42/flight-delay-dataset-2018-2024/versions/1/flight_data.parquet")

# %%
df_all.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2024        1      1          14          7  2024-01-14
# 1  2024        1      1          14          7  2024-01-14
# 2  2024        1      1          14          7  2024-01-14
# 3  2024        1      1          14          7  2024-01-14
# 4  2024        1      1          14          7  2024-01-14
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# 3                        UA                            UA_CODESHARE
# 4                        UA                            UA_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  Div5Airport  \
# 0                     19977                          UA  ...          NaN
# ...

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

print(df_all.head())
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2024        1      1          14          7  2024-01-14
# 1  2024        1      1          14          7  2024-01-14
# 2  2024        1      1          14          7  2024-01-14
# 3  2024        1      1          14          7  2024-01-14
# 4  2024        1      1          14          7  2024-01-14
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# 3                        UA                            UA_CODESHARE
# 4                        UA                            UA_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     19977                          UA
# 1                     19977                          UA
# ...

# %%
df_all.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        ...
#        'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn',
#        'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum',
#        'Duplicate', 'Unnamed: 119'],
#       dtype='object', length=120)

# %%
for col in df_all.columns:
    print(col)
# Out:
# Year
# Quarter
# Month
# DayofMonth
# DayOfWeek
# FlightDate
# Marketing_Airline_Network
# Operated_or_Branded_Code_Share_Partners
# DOT_ID_Marketing_Airline
# IATA_Code_Marketing_Airline
# Flight_Number_Marketing_Airline
# Originally_Scheduled_Code_Share_Airline
# DOT_ID_Originally_Scheduled_Code_Share_Airline
# IATA_Code_Originally_Scheduled_Code_Share_Airline
# Flight_Num_Originally_Scheduled_Code_Share_Airline
# Operating_Airline
# DOT_ID_Operating_Airline
# IATA_Code_Operating_Airline
# Tail_Number
# Flight_Number_Operating_Airline
# OriginAirportID
# OriginAirportSeqID
# OriginCityMarketID
# Origin
# OriginCityName
# OriginState
# OriginStateFips
# OriginStateName
# OriginWac
# DestAirportID
# DestAirportSeqID
# DestCityMarketID
# Dest
# DestCityName
# DestState
# DestStateFips
# DestStateName
# DestWac
# CRSDepTime
# DepTime
# DepDelay
# DepDelayMinutes
# DepDel15
# DepartureDelayGroups
# DepTimeBlk
# TaxiOut
# WheelsOff
# WheelsOn
# TaxiIn
# CRSArrTime
# ArrTime
# ArrDelay
# ...

# %%
df_all.shape
# Out:
# (582425, 120)

# %%
# Size of DataFrame in bytes
mem_bytes = df_all.memory_usage(deep=True).sum()

# Convert to human-readable format (MB)
mem_mb = mem_bytes / (1024**2)
print(f"Dataset size in memory: {mem_mb:.2f} MB")
# Out:
# Dataset size in memory: 1119.16 MB

# %%
counts = df_all.groupby('Year').size().reset_index(name='row_count')

print(counts)
# Out:
#    Year  row_count
# 0  2024     582425
